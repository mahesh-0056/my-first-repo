# %% [markdown]
# <a href="https://colab.research.google.com/github/mahesh-0056/my-first-repo/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! Gitub")
# Out:
# Hello! Gitub

# %%
print("mahesh")
# Out:
# mahesh
